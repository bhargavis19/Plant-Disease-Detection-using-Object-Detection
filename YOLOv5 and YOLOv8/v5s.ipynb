# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
os.chdir('D:/Computer Vision/Dataset')

# %%
os.getcwd()

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
# !yolo task=detect mode=train model=yolov5s.pt data=data.yaml epochs=100 imgsz=256 device=0

# %%
# !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=data.yaml
